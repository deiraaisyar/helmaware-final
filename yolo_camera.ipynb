# %%
from ultralytics import YOLO
import cv2
import time

# Load both models
fire_model = YOLO('fire.pt')
fire_model.names[0] = "fire"

smoke_model = YOLO('smoke_detection.pt')
smoke_model.names[0] = "smoke"

# Initialize video capture
cap = cv2.VideoCapture(0)

# Detection tracking (only fire & smoke)
detection_timers = {
    'fire': None,
    'smoke': None
}
detection_alerts = {
    'fire': False,
    'smoke': False
}

CONFIDENCE_THRESHOLD = 0.3
ALERT_DELAY_SECONDS = 2

while True:
    ret, frame = cap.read()
    if not ret:
        break

    resized_frame = cv2.resize(frame, (640, 480))
    annotated_frame = resized_frame.copy()  # start with raw frame

    # Run both models
    fire_results = fire_model(resized_frame)[0]
    smoke_results = smoke_model(resized_frame)[0]

    # Reset detection flags
    label_detected = {'fire': False, 'smoke': False}

    # Process and draw fire detections
    for box in fire_results.boxes:
        conf = float(box.conf)
        if conf > CONFIDENCE_THRESHOLD:
            x1, y1, x2, y2 = map(int, box.xyxy[0])
            label = "fire"
            cv2.rectangle(annotated_frame, (x1, y1), (x2, y2), (0, 0, 255), 2)
            cv2.putText(annotated_frame, f"{label} {conf:.2f}", (x1, y1 - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 0, 255), 2)
            label_detected[label] = True

    # Process and draw smoke detections
    for box in smoke_results.boxes:
        conf = float(box.conf)
        if conf > CONFIDENCE_THRESHOLD:
            x1, y1, x2, y2 = map(int, box.xyxy[0])
            label = "smoke"
            cv2.rectangle(annotated_frame, (x1, y1), (x2, y2), (255, 165, 0), 2)
            cv2.putText(annotated_frame, f"{label} {conf:.2f}", (x1, y1 - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 165, 0), 2)
            label_detected[label] = True

    # Time check for alerts
    current_time = time.time()

    for label in detection_timers:
        if label_detected[label]:
            if detection_timers[label] is None:
                detection_timers[label] = current_time
            elif current_time - detection_timers[label] >= ALERT_DELAY_SECONDS:
                detection_alerts[label] = True
        else:
            detection_timers[label] = None
            detection_alerts[label] = False

    # Display alerts
    y_offset = 50
    for label, alert in detection_alerts.items():
        if alert:
            cv2.putText(
                annotated_frame,
                f"ALERT: {label.upper()} DETECTED!",
                (50, y_offset),
                cv2.FONT_HERSHEY_SIMPLEX,
                1,
                (0, 0, 255),
                2,
                cv2.LINE_AA
            )
            y_offset += 40
            print(f"{label.upper()} DETECTED")

    # Show the result
    cv2.imshow('Fire & Smoke Detection', annotated_frame)

    # Exit on ESC key
    if cv2.waitKey(1) == 27:
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 (no detections), 66.0ms
# Speed: 1.8ms preprocess, 66.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 215.5ms
# Speed: 1.9ms preprocess, 215.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 52.5ms
# Speed: 2.0ms preprocess, 52.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 201.8ms
# Speed: 1.1ms preprocess, 201.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 40.0ms
# Speed: 1.1ms preprocess, 40.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 188.5ms
# Speed: 1.1ms preprocess, 188.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 39.9ms
# Speed: 1.2ms preprocess, 39.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 192.8ms
# Speed: 0.8ms preprocess, 192.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 41.1ms
# Speed: 1.5ms preprocess, 41.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 195.7ms
# Speed: 1.0ms preprocess, 195.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 40.3ms
# Speed: 1.2ms preprocess, 40.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 197.9ms
# Speed: 1.0ms preprocess, 197.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 39.4ms
# Speed: 1.0ms preprocess, 39.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 186.0ms
# Speed: 1.1ms preprocess, 186.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 38.2ms
# Speed: 0.8ms preprocess, 38.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 193.8ms
# Speed: 1.2ms preprocess, 193.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 38.7ms
# Speed: 1.5ms preprocess, 38.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 190.1ms
# Speed: 1.3ms preprocess, 190.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 39.7ms
# Speed: 0.8ms preprocess, 39.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 218.3ms
# Speed: 1.0ms preprocess, 218.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 51.2ms
# Speed: 1.2ms preprocess, 51.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 203.5ms
# Speed: 1.1ms preprocess, 203.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 41.6ms
# Speed: 1.0ms preprocess, 41.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 smoke, 191.7ms
# Speed: 1.5ms preprocess, 191.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 35.4ms
# Speed: 1.6ms preprocess, 35.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 190.2ms
# Speed: 1.1ms preprocess, 190.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 35.9ms
# Speed: 1.1ms preprocess, 35.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 184.5ms
# Speed: 0.7ms preprocess, 184.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 36.5ms
# Speed: 1.1ms preprocess, 36.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 182.6ms
# Speed: 0.9ms preprocess, 182.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 35.1ms
# Speed: 0.9ms preprocess, 35.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 182.0ms
# Speed: 0.9ms preprocess, 182.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 36.0ms
# Speed: 1.7ms preprocess, 36.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 209.0ms
# Speed: 1.0ms preprocess, 209.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 36.2ms
# Speed: 0.9ms preprocess, 36.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 189.6ms
# Speed: 1.2ms preprocess, 189.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 37.9ms
# Speed: 1.0ms preprocess, 37.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 194.9ms
# Speed: 1.1ms preprocess, 194.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 40.1ms
# Speed: 1.0ms preprocess, 40.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 186.5ms
# Speed: 1.3ms preprocess, 186.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 36.2ms
# Speed: 1.6ms preprocess, 36.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 187.1ms
# Speed: 0.9ms preprocess, 187.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 36.4ms
# Speed: 1.1ms preprocess, 36.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 186.4ms
# Speed: 1.1ms preprocess, 186.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 36.5ms
# Speed: 1.0ms preprocess, 36.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 188.8ms
# Speed: 1.1ms preprocess, 188.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 38.3ms
# Speed: 1.0ms preprocess, 38.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 185.3ms
# Speed: 1.1ms preprocess, 185.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 fire custom model_2 - v7 2024-05-21 5-56ams, 38.0ms
# Speed: 1.0ms preprocess, 38.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 181.9ms
# Speed: 1.5ms preprocess, 181.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 37.5ms
# Speed: 0.7ms preprocess, 37.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 187.9ms
# Speed: 1.3ms preprocess, 187.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 fire custom model_2 - v7 2024-05-21 5-56am, 39.3ms
# Speed: 1.1ms preprocess, 39.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 182.6ms
# Speed: 1.1ms preprocess, 182.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 fire custom model_2 - v7 2024-05-21 5-56am, 38.3ms
# Speed: 1.1ms preprocess, 38.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 181.8ms
# Speed: 1.1ms preprocess, 181.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 fire custom model_2 - v7 2024-05-21 5-56am, 39.3ms
# Speed: 0.9ms preprocess, 39.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 186.8ms
# Speed: 0.9ms preprocess, 186.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 fire custom model_2 - v7 2024-05-21 5-56am, 37.0ms
# Speed: 1.9ms preprocess, 37.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 185.3ms
# Speed: 1.1ms preprocess, 185.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 fire custom model_2 - v7 2024-05-21 5-56am, 34.8ms
# Speed: 1.2ms preprocess, 34.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 185.2ms
# Speed: 1.1ms preprocess, 185.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 37.1ms
# Speed: 0.9ms preprocess, 37.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 182.8ms
# Speed: 1.0ms preprocess, 182.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 fire custom model_2 - v7 2024-05-21 5-56am, 36.4ms
# Speed: 1.0ms preprocess, 36.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 182.3ms
# Speed: 1.2ms preprocess, 182.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 36.6ms
# Speed: 1.7ms preprocess, 36.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 182.7ms
# Speed: 0.9ms preprocess, 182.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 45.7ms
# Speed: 0.9ms preprocess, 45.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 185.5ms
# Speed: 1.0ms preprocess, 185.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 36.9ms
# Speed: 0.9ms preprocess, 36.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 182.2ms
# Speed: 1.2ms preprocess, 182.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 35.2ms
# Speed: 0.9ms preprocess, 35.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 180.4ms
# Speed: 0.9ms preprocess, 180.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 36.9ms
# Speed: 1.7ms preprocess, 36.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 182.3ms
# Speed: 0.8ms preprocess, 182.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 36.2ms
# Speed: 1.1ms preprocess, 36.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 185.6ms
# Speed: 1.1ms preprocess, 185.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 37.4ms
# Speed: 1.2ms preprocess, 37.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 194.4ms
# Speed: 1.0ms preprocess, 194.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 37.9ms
# Speed: 0.9ms preprocess, 37.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 186.6ms
# Speed: 1.0ms preprocess, 186.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 37.7ms
# Speed: 1.7ms preprocess, 37.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 186.9ms
# Speed: 1.1ms preprocess, 186.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 38.9ms
# Speed: 1.0ms preprocess, 38.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 190.9ms
# Speed: 0.9ms preprocess, 190.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 38.5ms
# Speed: 1.0ms preprocess, 38.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 187.8ms
# Speed: 1.1ms preprocess, 187.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 37.4ms
# Speed: 1.0ms preprocess, 37.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 187.4ms
# Speed: 1.1ms preprocess, 187.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 36.7ms
# Speed: 2.2ms preprocess, 36.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 188.3ms
# Speed: 0.9ms preprocess, 188.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 36.7ms
# Speed: 1.0ms preprocess, 36.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 181.7ms
# Speed: 0.8ms preprocess, 181.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
